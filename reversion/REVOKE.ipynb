-- %%
%sql
REVOKE ALL PRIVILEGES ON CATALOG proyectofinal from `DataOffice`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyectofinal.bronze from `DataOffice`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyectofinal.silver from `DataOffice`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyectofinal.golden from `DataOffice`;

-- %%
%sql
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` from `DataOffice`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` from `DataOffice`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` from `DataOffice`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` from `DataOffice`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` from `DataOffice`;
