-- %%
%sql
GRANT ALL PRIVILEGES ON CATALOG proyectofinal TO `DataOffice`;

GRANT USE SCHEMA ON SCHEMA proyectofinal.bronze TO `DataOffice`;
GRANT CREATE ON SCHEMA proyectofinal.bronze TO `DataOffice`;

GRANT USE SCHEMA ON SCHEMA proyectofinal.silver TO `DataOffice`;
GRANT CREATE ON SCHEMA proyectofinal.silver TO `DataOffice`;

GRANT USE SCHEMA ON SCHEMA proyectofinal.golden TO `DataOffice`;
GRANT CREATE ON SCHEMA proyectofinal.golden TO `DataOffice`;

-- %%
%sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` to `DataOffice`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` to `DataOffice`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` to `DataOffice`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` to `DataOffice`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` to `DataOffice`;
